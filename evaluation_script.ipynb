# %%
import torch
import cv2
import numpy as np
from ultralytics import YOLO
import os

# %%
# Path to your video frames and label files
frames_dir = 'D:\Datasets\DAta_intern\V9T5\images'
labels_dir = 'D:\Datasets\DAta_intern\V9T5\labels'
model_path = "D:\VS Code Folders\Squash-Ball-Tracking\Squash-Ball-Detection\\results_after_75_epochs\weights\\best.pt"

# %%
# Output video settings
output_video_path = 'output_video.mp4'
output_fps = 30

# %%
model = YOLO(model_path)

# %%
# Function to draw ground truth and predictions on each frame
def draw_detections(image, ground_truths):
    # Draw ground truth (green dot)
    for gt in ground_truths:
        x, y = int(gt[1]), int(gt[2])
        cv2.drawMarker(image, (x, y), color=[0, 255, 0], thickness=1, 
        markerType= cv2.MARKER_CROSS, line_type=cv2.LINE_AA,
        markerSize=10)
        overlay = image.copy()
        cv2.circle(overlay, (x, y), 10, (0, 0, 255), -1)  # Filled red circle
        cv2.addWeighted(overlay, 0.3, image, 0.7, 0, image)  # Blend the overlay with less intensity
    
    return image

# %%
# Function to read annotations from label file
def read_annotations(label_file):
    with open(label_file, 'r') as file:
        annotations = []
        for line in file.readlines():
            parts = line.strip().split()
            class_id = int(parts[0])
            center_x = float(parts[1])
            center_y = float(parts[2])
            width = float(parts[3])
            height = float(parts[4])
            annotations.append((class_id, center_x, center_y, width, height))
        return annotations

# %%
# Function to convert normalized annotations to pixel values
def convert_annotations_to_pixels(annotations, image_width, image_height):
    pixel_annotations = []
    for annotation in annotations:
        class_id, center_x, center_y, width, height = annotation
        center_x = int(center_x * image_width)
        center_y = int(center_y * image_height)
        pixel_annotations.append((class_id, center_x, center_y, width, height))
    return pixel_annotations

# %%
# Function to check if prediction is inside the red circle
def is_inside_circle(pred_x, pred_y, gt_x, gt_y, radius=10):
    distance_squared = np.sqrt((pred_x - gt_x)**2 + (pred_y - gt_y)**2)
    return distance_squared <= radius

# %%
frame_paths = []
for frame in os.listdir(frames_dir):
    if frame.endswith('.jpg'):
        frame_paths.append(os.path.join(frames_dir, frame))

# %%
# Initialize video writer
frame = cv2.imread(frame_paths[0])
height, width, _ = frame.shape
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_video_path, fourcc, output_fps, (width, height))
print(height, width)
# Out:
# 640 640

# %%
TP = 0
FP = 0
FN = 0
F1 = 0
# Process each frame
for frame_path in frame_paths:
    # Read frame
    frame = cv2.imread(frame_path)
    
    # Read corresponding label file
    frame_name = os.path.splitext(os.path.basename(frame_path))[0]
    label_file = os.path.join(labels_dir, frame_name) + '.txt'
    
    ground_truths = read_annotations(label_file)
    ground_truths = convert_annotations_to_pixels(ground_truths, width, height)
    
    # Make predictions
    predictions = model.predict(frame)
    
    # Extracting bounding box center coordinates for predictions
    prediction_centers = []
    prediction_confidences = []
    for pred in predictions[0].boxes:
        if pred.conf > 0.1:  # You can set a threshold for confidence
            bbox = pred.xyxy[0]  # xyxy format
            x_center = (bbox[0] + bbox[2]) / 2
            y_center = (bbox[1] + bbox[3]) / 2
            prediction_centers.append([x_center.item(), y_center.item()])
            prediction_confidences.append(pred.conf)

    # Draw ground truth and predictions on the frame
    annotated_frame = draw_detections(frame, ground_truths)
    cv2.putText(annotated_frame, f'Ground Truth: {ground_truths}', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
    cv2.putText(annotated_frame, f'Predictions: {prediction_centers}', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)

    # Track which ground truths have been matched
    matched_ground_truths = set()
    
    # Check true positives and false positives
    for j, pred in enumerate(prediction_centers):
        pred_x, pred_y = pred[0], pred[1]
        matched = False
        for i, gt in enumerate(ground_truths):
            gt_x, gt_y = gt[1], gt[2]
            
            print("g_x: ", gt_x)
            print('gt_y: ', gt_y)
            print('pred_x: ', pred_x)
            print('pred_y: ', pred_y)

            if is_inside_circle(pred_x, pred_y, gt_x, gt_y, radius=10):
                # True positive (prediction inside the red circle)
                cv2.putText(annotated_frame, 'True Positive', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
                matched_ground_truths.add(i)
                matched = True
                TP += prediction_confidences[j]
                break
        if not matched:
            # False positive (prediction outside the red circle)
            cv2.putText(annotated_frame, 'False Positive', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
            FP += prediction_confidences[j]

    # Check for false negatives (ground truths with no matching predictions)
    for i, gt in enumerate(ground_truths):
        if i not in matched_ground_truths:
            gt_x, gt_y = gt[1], gt[2]
            cv2.putText(annotated_frame, 'False Negative', (10,60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
            FN += 1

    # Write frame to the output video
    out.write(annotated_frame)
    
    # Display the frame (optional)
    cv2.imshow('Frame', annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 (no detections), 383.5ms
# Speed: 11.0ms preprocess, 383.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 805.2ms
# Speed: 15.0ms preprocess, 805.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 381.9ms
# Speed: 9.0ms preprocess, 381.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 332.6ms
# Speed: 9.9ms preprocess, 332.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 340.7ms
# Speed: 7.0ms preprocess, 340.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 308.5ms
# Speed: 8.0ms preprocess, 308.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 299.1ms
# Speed: 8.0ms preprocess, 299.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  230
# gt_y:  299
# pred_x:  230.26039123535156
# pred_y:  299.44036865234375
#
# 0: 640x640 (no detections), 325.1ms
# Speed: 8.0ms preprocess, 325.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 424.7ms
# Speed: 7.0ms preprocess, 424.7ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  235
# gt_y:  305
# pred_x:  235.29852294921875
# pred_y:  303.78485107421875
#
# 0: 640x640 1 ball, 480.6ms
# Speed: 18.5ms preprocess, 480.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  236
# gt_y:  308
# pred_x:  237.24569702148438
# pred_y:  306.8056640625
#
# 0: 640x640 1 ball, 370.2ms
# Speed: 9.0ms preprocess, 370.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  238
# gt_y:  307
# pred_x:  238.4566192626953
# pred_y:  306.72332763671875
#
# 0: 640x640 1 ball, 336.0ms
# Speed: 24.1ms preprocess, 336.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  238
# gt_y:  307
# pred_x:  238.41334533691406
# pred_y:  306.626708984375
#
# 0: 640x640 (no detections), 314.5ms
# Speed: 7.0ms preprocess, 314.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 326.4ms
# Speed: 9.0ms preprocess, 326.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 377.6ms
# Speed: 8.0ms preprocess, 377.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  241
# gt_y:  309
# pred_x:  241.51565551757812
# pred_y:  308.2079162597656
#
# 0: 640x640 1 ball, 333.1ms
# Speed: 9.0ms preprocess, 333.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  242
# gt_y:  311
# pred_x:  242.27957153320312
# pred_y:  309.41204833984375
#
# 0: 640x640 (no detections), 397.1ms
# Speed: 11.0ms preprocess, 397.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 316.4ms
# Speed: 8.0ms preprocess, 316.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 497.1ms
# Speed: 7.0ms preprocess, 497.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  245
# gt_y:  313
# pred_x:  244.34445190429688
# pred_y:  310.3245849609375
#
# 0: 640x640 (no detections), 346.8ms
# Speed: 6.0ms preprocess, 346.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 321.8ms
# Speed: 7.8ms preprocess, 321.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 283.3ms
# Speed: 8.1ms preprocess, 283.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 293.2ms
# Speed: 7.0ms preprocess, 293.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  248
# gt_y:  314
# pred_x:  247.34051513671875
# pred_y:  313.627685546875
#
# 0: 640x640 (no detections), 305.9ms
# Speed: 7.0ms preprocess, 305.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 278.9ms
# Speed: 6.0ms preprocess, 278.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  250
# gt_y:  315
# pred_x:  250.17613220214844
# pred_y:  315.3593444824219
#
# 0: 640x640 1 ball, 305.2ms
# Speed: 8.0ms preprocess, 305.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  251
# gt_y:  317
# pred_x:  251.22952270507812
# pred_y:  315.69085693359375
#
# 0: 640x640 1 ball, 352.6ms
# Speed: 9.0ms preprocess, 352.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  251
# gt_y:  316
# pred_x:  251.22682189941406
# pred_y:  315.6901550292969
#
# 0: 640x640 1 ball, 301.6ms
# Speed: 7.0ms preprocess, 301.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  253
# gt_y:  317
# pred_x:  252.69140625
# pred_y:  316.06378173828125
#
# 0: 640x640 1 ball, 520.9ms
# Speed: 10.0ms preprocess, 520.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  253
# gt_y:  318
# pred_x:  254.17193603515625
# pred_y:  316.6501770019531
#
# 0: 640x640 (no detections), 293.8ms
# Speed: 8.0ms preprocess, 293.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 279.4ms
# Speed: 9.6ms preprocess, 279.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 281.7ms
# Speed: 7.0ms preprocess, 281.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 348.5ms
# Speed: 8.0ms preprocess, 348.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 304.1ms
# Speed: 6.0ms preprocess, 304.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 332.5ms
# Speed: 7.0ms preprocess, 332.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  259
# gt_y:  322
# pred_x:  258.64837646484375
# pred_y:  321.4161376953125
#
# 0: 640x640 1 ball, 401.2ms
# Speed: 11.0ms preprocess, 401.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  261
# gt_y:  325
# pred_x:  260.72509765625
# pred_y:  323.2255554199219
#
# 0: 640x640 1 ball, 372.4ms
# Speed: 10.0ms preprocess, 372.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  263
# gt_y:  323
# pred_x:  261.68072509765625
# pred_y:  323.51446533203125
#
# 0: 640x640 1 ball, 335.9ms
# Speed: 10.0ms preprocess, 335.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  262
# gt_y:  324
# pred_x:  261.6802978515625
# pred_y:  323.514892578125
#
# 0: 640x640 (no detections), 332.5ms
# Speed: 8.0ms preprocess, 332.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 296.2ms
# Speed: 8.0ms preprocess, 296.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 278.2ms
# Speed: 8.0ms preprocess, 278.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 300.3ms
# Speed: 8.0ms preprocess, 300.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 302.3ms
# Speed: 6.0ms preprocess, 302.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 305.0ms
# Speed: 8.0ms preprocess, 305.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 362.5ms
# Speed: 13.0ms preprocess, 362.5ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 298.8ms
# Speed: 7.9ms preprocess, 298.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 301.4ms
# Speed: 9.0ms preprocess, 301.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 281.5ms
# Speed: 8.0ms preprocess, 281.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 278.9ms
# Speed: 7.0ms preprocess, 278.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 355.2ms
# Speed: 102.0ms preprocess, 355.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 324.8ms
# Speed: 8.0ms preprocess, 324.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:
6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  358
# gt_y:  172
# pred_x:  357.80487060546875
# pred_y:  172.6338348388672
#
# 0: 640x640 1 ball, 322.9ms
# Speed: 8.0ms preprocess, 322.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  340
# gt_y:  148
# pred_x:  345.7977294921875
# pred_y:  152.09213256835938
#
# 0: 640x640 1 ball, 349.8ms
# Speed: 8.0ms preprocess, 349.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 373.5ms
# Speed: 9.0ms preprocess, 373.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 405.6ms
# Speed: 7.0ms preprocess, 405.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 442.4ms
# Speed: 9.0ms preprocess, 442.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 621.0ms
# Speed: 9.0ms preprocess, 621.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 394.5ms
# Speed: 17.7ms preprocess, 394.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 401.7ms
# Speed: 8.0ms preprocess, 401.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 382.5ms
# Speed: 7.0ms preprocess, 382.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 463.3ms
# Speed: 10.2ms preprocess, 463.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  299
# gt_y:  138
# pred_x:  298.568603515625
# pred_y:  139.36651611328125
#
# 0: 640x640 2 balls, 450.4ms
# Speed: 10.0ms preprocess, 450.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  292
# gt_y:  142
# pred_x:  291.92779541015625
# pred_y:  142.083251953125
# g_x:  292
# gt_y:  142
# pred_x:  291.79876708984375
# pred_y:  142.54220581054688
#
# 0: 640x640 2 balls, 404.6ms
# Speed: 9.7ms preprocess, 404.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  283
# gt_y:  148
# pred_x:  283.89190673828125
# pred_y:  147.6604766845703
# g_x:  283
# gt_y:  148
# pred_x:  283.68182373046875
# pred_y:  146.85903930664062
#
# 0: 640x640 1 ball, 390.0ms
# Speed: 6.0ms preprocess, 390.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  275
# gt_y:  152
# pred_x:  275.739990234375
# pred_y:  152.37509155273438
#
# 0: 640x640 1 ball, 384.1ms
# Speed: 10.0ms preprocess, 384.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  275
# gt_y:  152
# pred_x:  275.74041748046875
# pred_y:  152.37542724609375
#
# 0: 640x640 1 ball, 470.1ms
# Speed: 7.0ms preprocess, 470.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  266
# gt_y:  161
# pred_x:  266.8172607421875
# pred_y:  160.174560546875
#
# 0: 640x640 1 ball, 973.2ms
# Speed: 13.4ms preprocess, 973.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  258
# gt_y:  171
# pred_x:  257.210205078125
# pred_y:  169.23846435546875
#
# 0: 640x640 3 balls, 471.5ms
# Speed: 8.0ms preprocess, 471.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  247
# gt_y:  182
# pred_x:  246.6436004638672
# pred_y:  182.52764892578125
# g_x:  247
# gt_y:  182
# pred_x:  248.35096740722656
# pred_y:  182.603515625
# g_x:  247
# gt_y:  182
# pred_x:  248.47836303710938
# pred_y:  182.2802276611328
#
# 0: 640x640 (no detections), 412.6ms
# Speed: 11.0ms preprocess, 412.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 466.1ms
# Speed: 10.0ms preprocess, 466.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 378.7ms
# Speed: 11.0ms preprocess, 378.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  223
# gt_y:  218
# pred_x:  225.4014892578125
# pred_y:  213.53457641601562
#
# 0: 640x640 1 ball, 448.9ms
# Speed: 9.0ms preprocess, 448.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  212
# gt_y:  233
# pred_x:  213.8431396484375
# pred_y:  229.99435424804688
#
# 0: 640x640 2 balls, 420.0ms
# Speed: 8.0ms preprocess, 420.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  198
# gt_y:  258
# pred_x:  201.28594970703125
# pred_y:  253.22311401367188
# g_x:  198
# gt_y:  258
# pred_x:  201.19198608398438
# pred_y:  253.03773498535156
#
# 0: 640x640 2 balls, 390.2ms
# Speed: 13.0ms preprocess, 390.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  198
# gt_y:  257
# pred_x:  201.28433227539062
# pred_y:  253.2248077392578
# g_x:  198
# gt_y:  257
# pred_x:  201.1912841796875
# pred_y:  253.03811645507812
#
# 0: 640x640 (no detections), 488.6ms
# Speed: 7.0ms preprocess, 488.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 430.2ms
# Speed: 10.3ms preprocess, 430.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 578.2ms
# Speed: 10.0ms preprocess, 578.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 407.7ms
# Speed: 9.0ms preprocess, 407.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 388.2ms
# Speed: 6.0ms preprocess, 388.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 511.9ms
# Speed: 12.5ms preprocess, 511.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 419.7ms
# Speed: 8.0ms preprocess, 419.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 409.5ms
# Speed: 7.0ms preprocess, 409.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 386.8ms
# Speed: 8.0ms preprocess, 386.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 359.1ms
# Speed: 8.0ms preprocess, 359.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 650.6ms
# Speed: 12.1ms preprocess, 650.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 543.8ms
# Speed: 16.0ms preprocess, 543.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 462.5ms
# Speed: 12.0ms preprocess, 462.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  378
# gt_y:  241
# pred_x:  377.89202880859375
# pred_y:  240.69064331054688
#
# 0: 640x640 1 ball, 387.6ms
# Speed: 20.0ms preprocess, 387.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  385
# gt_y:  249
# pred_x:  384.8265380859375
# pred_y:  248.09339904785156
#
# 0: 640x640 1 ball, 441.6ms
# Speed: 15.0ms preprocess, 441.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  391
# gt_y:  255
# pred_x:  390.34918212890625
# pred_y:  254.03285217285156
#
# 0: 640x640 1 ball, 422.8ms
# Speed: 15.0ms preprocess, 422.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  393
# gt_y:  257
# pred_x:  390.3450012207031
# pred_y:  254.0460662841797
#
# 0: 640x640 (no detections), 415.6ms
# Speed: 8.0ms preprocess, 415.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 407.9ms
# Speed: 17.0ms preprocess, 407.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 393.2ms
# Speed: 8.0ms preprocess, 393.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 471.9ms
# Speed: 10.6ms preprocess, 471.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 482.8ms
# Speed: 10.0ms preprocess, 482.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 719.7ms
# Speed: 10.0ms preprocess, 719.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 410.3ms
# Speed: 10.0ms preprocess, 410.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  429
# gt_y:  301
# pred_x:  428.56439208984375
# pred_y:  300.19775390625
#
# 0: 640x640 2 balls, 509.6ms
# Speed: 15.1ms preprocess, 509.6ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  428
# gt_y:  298
# pred_x:  427.97845458984375
# pred_y:  298.2137145996094
# g_x:  428
# gt_y:  298
# pred_x:  428.12139892578125
# pred_y:  298.0101318359375
#
# 0: 640x640 1 ball, 448.0ms
# Speed: 15.3ms preprocess, 448.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  427
# gt_y:  296
# pred_x:  426.9507141113281
# pred_y:  296.89776611328125
#
# 0: 640x640 1 ball, 489.7ms
# Speed: 7.0ms preprocess, 489.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  426
# gt_y:  296
# pred_x:  426.9496765136719
# pred_y:  296.8993835449219
#
# 0: 640x640 1 ball, 400.9ms
# Speed: 12.0ms preprocess, 400.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  426
# gt_y:  296
# pred_x:  426.949951171875
# pred_y:  296.8988037109375
#
# 0: 640x640 3 balls, 424.3ms
# Speed: 8.0ms preprocess, 424.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  425
# gt_y:  294
# pred_x:  425.3461608886719
# pred_y:  293.962890625
# g_x:  425
# gt_y:  294
# pred_x:  423.177734375
# pred_y:  293.3355407714844
# g_x:  425
# gt_y:  294
# pred_x:  425.55938720703125
# pred_y:  294.0842590332031
#
# 0: 640x640 1 ball, 536.2ms
# Speed: 10.0ms preprocess, 536.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  425
# gt_y:  293
# pred_x:  423.1373291015625
# pred_y:  293.27685546875
#
# 0: 640x640 (no detections), 397.5ms
# Speed: 8.0ms preprocess, 397.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 447.4ms
# Speed: 9.0ms preprocess, 447.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 389.5ms
# Speed: 12.0ms preprocess, 389.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 394.5ms
# Speed: 8.0ms preprocess, 394.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 480.5ms
# Speed: 9.0ms preprocess, 480.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 384.2ms
# Speed: 12.7ms preprocess, 384.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 balls, 385.7ms
# Speed: 12.0ms preprocess, 385.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  414
# gt_y:  323
# pred_x:  413.6957702636719
# pred_y:  322.9573059082031
# g_x:  414
# gt_y:  323
# pred_x:  413.52777099609375
# pred_y:  322.6624450683594
#
# 0: 640x640 1 ball, 400.5ms
# Speed: 8.0ms preprocess, 400.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  414
# gt_y:  325
# pred_x:  413.79803466796875
# pred_y:  322.91998291015625
#
# 0: 640x640 1 ball, 377.1ms
# Speed: 8.0ms preprocess, 377.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  412
# gt_y:  332
# pred_x:  412.72979736328125
# pred_y:  332.1560974121094
#
# 0: 640x640 (no detections), 477.7ms
# Speed: 15.5ms preprocess, 477.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 392.0ms
# Speed: 9.0ms preprocess, 392.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 429.8ms
# Speed: 7.0ms preprocess, 429.8ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 404.4ms
# Speed: 7.0ms preprocess, 404.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 371.4ms
# Speed: 9.6ms preprocess, 371.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 502.2ms
# Speed: 14.0ms preprocess, 502.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 808.1ms
# Speed: 14.0ms preprocess, 808.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  307
# gt_y:  243
# pred_x:  308.044921875
# pred_y:  243.6314697265625
#
# 0: 640x640 1 ball, 330.8ms
# Speed: 7.0ms preprocess, 330.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  289
# gt_y:  231
# pred_x:  291.26727294921875
# ...
# Speed: 7.0ms preprocess, 485.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 490.5ms
# Speed: 9.0ms preprocess, 490.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 441.1ms
# Speed: 22.0ms preprocess, 441.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 435.3ms
# Speed: 9.0ms preprocess, 435.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 424.9ms
# Speed: 11.0ms preprocess, 424.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 526.8ms
# Speed: 10.0ms preprocess, 526.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 388.0ms
# Speed: 7.0ms preprocess, 388.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 402.9ms
# Speed: 10.0ms preprocess, 402.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 415.4ms
# Speed: 110.0ms preprocess, 415.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 475.0ms
# Speed: 10.0ms preprocess, 475.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 533.9ms
# Speed: 17.0ms preprocess, 533.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 514.4ms
# Speed: 8.0ms preprocess, 514.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 386.1ms
# Speed: 8.0ms preprocess, 386.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 374.1ms
# Speed: 11.2ms preprocess, 374.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 406.0ms
# Speed: 14.0ms preprocess, 406.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 457.6ms
# Speed: 16.5ms preprocess, 457.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 466.4ms
# Speed: 6.0ms preprocess, 466.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 440.8ms
# Speed: 12.0ms preprocess, 440.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 384.4ms
# Speed: 11.0ms preprocess, 384.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 404.2ms
# Speed: 11.4ms preprocess, 404.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 436.3ms
# Speed: 17.1ms preprocess, 436.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 400.6ms
# Speed: 9.0ms preprocess, 400.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 433.5ms
# Speed: 17.0ms preprocess, 433.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 354.3ms
# Speed: 8.0ms preprocess, 354.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 358.1ms
# Speed: 9.0ms preprocess, 358.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 502.0ms
# Speed: 38.0ms preprocess, 502.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 367.6ms
# Speed: 8.0ms preprocess, 367.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 354.1ms
# Speed: 12.0ms preprocess, 354.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 351.0ms
# Speed: 9.0ms preprocess, 351.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 356.7ms
# Speed: 10.0ms preprocess, 356.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 406.6ms
# Speed: 11.0ms preprocess, 406.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 399.5ms
# Speed: 9.7ms preprocess, 399.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 379.2ms
# Speed: 8.0ms preprocess, 379.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 354.0ms
# Speed: 8.4ms preprocess, 354.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 360.2ms
# Speed: 8.0ms preprocess, 360.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 356.3ms
# Speed: 8.0ms preprocess, 356.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 460.2ms
# Speed: 11.0ms preprocess, 460.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 352.1ms
# Speed: 9.0ms preprocess, 352.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 376.1ms
# Speed: 10.0ms preprocess, 376.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 369.8ms
# Speed: 9.0ms preprocess, 369.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 354.9ms
# Speed: 12.0ms preprocess, 354.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 420.2ms
# Speed: 7.0ms preprocess, 420.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 588.1ms
# Speed: 14.0ms preprocess, 588.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  380
# gt_y:  359
# pred_x:  379.2965087890625
# pred_y:  358.5938720703125
#
# 0: 640x640 2 balls, 355.5ms
# Speed: 7.0ms preprocess, 355.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  379
# gt_y:  352
# pred_x:  379.16546630859375
# pred_y:  351.29046630859375
# g_x:  379
# gt_y:  352
# pred_x:  378.963623046875
# pred_y:  350.811767578125
#
# 0: 640x640 2 balls, 362.5ms
# Speed: 7.0ms preprocess, 362.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  379
# gt_y:  353
# pred_x:  379.16534423828125
# pred_y:  351.2857360839844
# g_x:  379
# gt_y:  353
# pred_x:  378.96392822265625
# pred_y:  350.80975341796875
#
# 0: 640x640 2 balls, 367.4ms
# Speed: 8.0ms preprocess, 367.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  378
# gt_y:  345
# pred_x:  378.00933837890625
# pred_y:  344.97259521484375
# g_x:  378
# gt_y:  345
# pred_x:  378.4716796875
# pred_y:  345.04876708984375
#
# 0: 640x640 (no detections), 372.3ms
# Speed: 8.0ms preprocess, 372.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 442.7ms
# Speed: 12.0ms preprocess, 442.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 362.7ms
# Speed: 9.0ms preprocess, 362.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 392.2ms
# Speed: 10.0ms preprocess, 392.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 350.6ms
# Speed: 7.0ms preprocess, 350.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 388.0ms
# Speed: 8.0ms preprocess, 388.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 435.7ms
# Speed: 10.0ms preprocess, 435.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 441.7ms
# Speed: 10.0ms preprocess, 441.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 391.0ms
# Speed: 6.0ms preprocess, 391.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 424.8ms
# Speed: 12.0ms preprocess, 424.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 357.1ms
# Speed: 8.0ms preprocess, 357.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 367.3ms
# Speed: 10.0ms preprocess, 367.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  380
# gt_y:  349
# pred_x:  379.3165283203125
# pred_y:  348.27130126953125
#
# 0: 640x640 (no detections), 406.2ms
# Speed: 7.9ms preprocess, 406.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 350.3ms
# Speed: 8.0ms preprocess, 350.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 343.6ms
# Speed: 11.0ms preprocess, 343.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 572.4ms
# Speed: 10.1ms preprocess, 572.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 355.3ms
# Speed: 8.0ms preprocess, 355.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 452.2ms
# Speed: 10.0ms preprocess, 452.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 370.9ms
# Speed: 10.0ms preprocess, 370.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 346.9ms
# Speed: 7.0ms preprocess, 346.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 348.8ms
# Speed: 12.0ms preprocess, 348.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 347.0ms
# Speed: 8.0ms preprocess, 347.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 393.8ms
# Speed: 7.0ms preprocess, 393.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 417.0ms
# Speed: 9.6ms preprocess, 417.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 364.5ms
# Speed: 10.0ms preprocess, 364.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 377.7ms
# Speed: 5.0ms preprocess, 377.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 364.7ms
# Speed: 8.0ms preprocess, 364.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 338.1ms
# Speed: 8.0ms preprocess, 338.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 352.8ms
# Speed: 8.0ms preprocess, 352.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 367.2ms
# Speed: 10.1ms preprocess, 367.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 339.9ms
# Speed: 8.0ms preprocess, 339.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 359.0ms
# Speed: 9.0ms preprocess, 359.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 540.8ms
# Speed: 11.0ms preprocess, 540.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 608.1ms
# Speed: 10.0ms preprocess, 608.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 457.2ms
# Speed: 7.0ms preprocess, 457.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 357.8ms
# Speed: 8.0ms preprocess, 357.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 375.8ms
# Speed: 11.0ms preprocess, 375.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 430.8ms
# Speed: 24.0ms preprocess, 430.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 401.5ms
# Speed: 11.0ms preprocess, 401.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 560.6ms
# Speed: 12.0ms preprocess, 560.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 435.0ms
# Speed: 10.0ms preprocess, 435.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 714.2ms
# Speed: 103.7ms preprocess, 714.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 480.5ms
# Speed: 8.0ms preprocess, 480.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 615.8ms
# Speed: 11.0ms preprocess, 615.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 417.2ms
# Speed: 8.0ms preprocess, 417.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 428.2ms
# Speed: 9.0ms preprocess, 428.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 424.3ms
# Speed: 15.4ms preprocess, 424.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 364.6ms
# Speed: 9.0ms preprocess, 364.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 477.1ms
# Speed: 11.0ms preprocess, 477.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 458.4ms
# Speed: 9.0ms preprocess, 458.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 371.5ms
# Speed: 10.0ms preprocess, 371.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 562.7ms
# Speed: 12.0ms preprocess, 562.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 372.0ms
# Speed: 11.0ms preprocess, 372.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 423.3ms
# Speed: 13.0ms preprocess, 423.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 402.5ms
# Speed: 10.0ms preprocess, 402.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 701.4ms
# Speed: 9.0ms preprocess, 701.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 373.7ms
# Speed: 8.0ms preprocess, 373.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 391.4ms
# Speed: 7.0ms preprocess, 391.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 411.0ms
# Speed: 9.9ms preprocess, 411.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 368.9ms
# Speed: 8.0ms preprocess, 368.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 353.7ms
# Speed: 9.0ms preprocess, 353.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 368.2ms
# Speed: 14.0ms preprocess, 368.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 363.1ms
# Speed: 9.0ms preprocess, 363.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 451.8ms
# Speed: 10.0ms preprocess, 451.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 379.5ms
# Speed: 9.0ms preprocess, 379.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 358.0ms
# Speed: 10.5ms preprocess, 358.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 380.2ms
# Speed: 11.0ms preprocess, 380.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 544.4ms
# Speed: 8.0ms preprocess, 544.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
F1 = (2 * TP)/(2 * TP + FP + FN)
print(f'True Positive: {TP}')
print(f'False Positive: {FP}')
print(f'False Negative: {FN}')
print(f'F1 Score: {F1}')
# Out:
# True Positive: tensor([57.0042])
# False Positive: tensor([4.5853])
# False Negative: 276
# F1 Score: tensor([0.2889])
