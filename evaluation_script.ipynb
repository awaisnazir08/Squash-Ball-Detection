# %%
import torch
import cv2
import numpy as np
from ultralytics import YOLO
import os

# %%
# Path to your video frames and label files
frames_dir = 'D:\Datasets\DAta_intern\V9T4\images'
labels_dir = 'D:\Datasets\DAta_intern\V9T4\labels'
model_path = "D:\VS Code Folders\Squash-Ball-Tracking\Squash-Ball-Detection\\results_after_75_epochs\weights\\best.pt"

# %%
# Output video settings
output_video_path = 'output_video.mp4'
output_fps = 30

# %%
model = YOLO(model_path)

# %%
# Function to draw ground truth and predictions on each frame
def draw_detections(image, ground_truths):
    # Draw ground truth (green dot)
    for gt in ground_truths:
        x, y = int(gt[1]), int(gt[2])
        cv2.drawMarker(image, (x, y), color=[0, 255, 0], thickness=1, 
        markerType= cv2.MARKER_CROSS, line_type=cv2.LINE_AA,
        markerSize=10)
        overlay = image.copy()
        cv2.circle(overlay, (x, y), 10, (0, 0, 255), -1)  # Filled red circle
        cv2.addWeighted(overlay, 0.3, image, 0.7, 0, image)  # Blend the overlay with less intensity
    
    return image

# %%
# Function to read annotations from label file
def read_annotations(label_file):
    with open(label_file, 'r') as file:
        annotations = []
        for line in file.readlines():
            parts = line.strip().split()
            class_id = int(parts[0])
            center_x = float(parts[1])
            center_y = float(parts[2])
            width = float(parts[3])
            height = float(parts[4])
            annotations.append((class_id, center_x, center_y, width, height))
        return annotations

# %%
# Function to convert normalized annotations to pixel values
def convert_annotations_to_pixels(annotations, image_width, image_height):
    pixel_annotations = []
    for annotation in annotations:
        class_id, center_x, center_y, width, height = annotation
        center_x = int(center_x * image_width)
        center_y = int(center_y * image_height)
        pixel_annotations.append((class_id, center_x, center_y, width, height))
    return pixel_annotations

# %%
# Function to check if prediction is inside the red circle
def is_inside_circle(pred_x, pred_y, gt_x, gt_y, radius=10):
    distance_squared = np.sqrt((pred_x - gt_x)**2 + (pred_y - gt_y)**2)
    return distance_squared <= radius

# %%
frame_paths = []
for frame in os.listdir(frames_dir):
    if frame.endswith('.jpg'):
        frame_paths.append(os.path.join(frames_dir, frame))

# %%
# Initialize video writer
frame = cv2.imread(frame_paths[0])
height, width, _ = frame.shape
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_video_path, fourcc, output_fps, (width, height))
print(height, width)
# Out:
# 640 640

# %%
TP = 0
FP = 0
FN = 0
F1 = 0
# Process each frame
for frame_path in frame_paths:
    # Read frame
    frame = cv2.imread(frame_path)
    
    # Read corresponding label file
    frame_name = os.path.splitext(os.path.basename(frame_path))[0]
    label_file = os.path.join(labels_dir, frame_name) + '.txt'
    
    ground_truths = read_annotations(label_file)
    ground_truths = convert_annotations_to_pixels(ground_truths, width, height)
    
    # Make predictions
    predictions = model.predict(frame)
    
    # Extracting bounding box center coordinates for predictions
    prediction_centers = []
    prediction_confidences = []
    for pred in predictions[0].boxes:
        if pred.conf > 0.1:  # You can set a threshold for confidence
            bbox = pred.xyxy[0]  # xyxy format
            x_center = (bbox[0] + bbox[2]) / 2
            y_center = (bbox[1] + bbox[3]) / 2
            prediction_centers.append([x_center.item(), y_center.item()])
            prediction_confidences.append(pred.conf)

    # Draw ground truth and predictions on the frame
    annotated_frame = draw_detections(frame, ground_truths)
    cv2.putText(annotated_frame, f'Ground Truth: {ground_truths}', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
    cv2.putText(annotated_frame, f'Predictions: {prediction_centers}', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)

    # Track which ground truths have been matched
    matched_ground_truths = set()
    
    # Check true positives and false positives
    for j, pred in enumerate(prediction_centers):
        pred_x, pred_y = pred[0], pred[1]
        matched = False
        for i, gt in enumerate(ground_truths):
            gt_x, gt_y = gt[1], gt[2]
            
            print("g_x: ", gt_x)
            print('gt_y: ', gt_y)
            print('pred_x: ', pred_x)
            print('pred_y: ', pred_y)

            if is_inside_circle(pred_x, pred_y, gt_x, gt_y, radius=10):
                # True positive (prediction inside the red circle)
                cv2.putText(annotated_frame, 'True Positive', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
                matched_ground_truths.add(i)
                matched = True
                TP += prediction_confidences[j]
                break
        if not matched:
            # False positive (prediction outside the red circle)
            cv2.putText(annotated_frame, 'False Positive', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
            FP += prediction_confidences[j]

    # Check for false negatives (ground truths with no matching predictions)
    for i, gt in enumerate(ground_truths):
        if i not in matched_ground_truths:
            gt_x, gt_y = gt[1], gt[2]
            cv2.putText(annotated_frame, 'False Negative', (10,60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
            FN += 1

    # Write frame to the output video
    out.write(annotated_frame)
    
    # Display the frame (optional)
    cv2.imshow('Frame', annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 2 balls, 394.5ms
# Speed: 12.8ms preprocess, 394.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  291
# gt_y:  239
# pred_x:  290.26092529296875
# pred_y:  239.04818725585938
# g_x:  291
# gt_y:  239
# pred_x:  290.2835388183594
# pred_y:  238.92971801757812
#
# 0: 640x640 2 balls, 778.5ms
# Speed: 18.2ms preprocess, 778.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  282
# gt_y:  249
# pred_x:  282.443603515625
# pred_y:  250.13539123535156
# g_x:  282
# gt_y:  249
# pred_x:  282.7064208984375
# pred_y:  249.75048828125
#
# 0: 640x640 (no detections), 465.6ms
# Speed: 16.0ms preprocess, 465.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 343.2ms
# Speed: 8.0ms preprocess, 343.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 310.2ms
# Speed: 9.8ms preprocess, 310.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 388.1ms
# Speed: 7.0ms preprocess, 388.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 344.0ms
# Speed: 8.0ms preprocess, 344.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 687.3ms
# Speed: 10.0ms preprocess, 687.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 465.1ms
# Speed: 9.7ms preprocess, 465.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  242
# gt_y:  310
# pred_x:  242.2119903564453
# pred_y:  309.65032958984375
#
# 0: 640x640 1 ball, 401.1ms
# Speed: 31.1ms preprocess, 401.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  242
# gt_y:  310
# pred_x:  242.42349243164062
# pred_y:  309.90087890625
#
# 0: 640x640 1 ball, 432.9ms
# Speed: 6.0ms preprocess, 432.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  238
# gt_y:  306
# pred_x:  237.943115234375
# pred_y:  306.6577453613281
#
# 0: 640x640 1 ball, 394.3ms
# Speed: 9.8ms preprocess, 394.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  233
# gt_y:  303
# pred_x:  234.63197326660156
# pred_y:  302.5794372558594
#
# 0: 640x640 1 ball, 330.9ms
# Speed: 8.7ms preprocess, 330.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  233
# gt_y:  303
# pred_x:  234.7171630859375
# pred_y:  302.51690673828125
#
# 0: 640x640 1 ball, 291.9ms
# Speed: 7.0ms preprocess, 291.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  233
# gt_y:  303
# pred_x:  234.71298217773438
# pred_y:  302.53857421875
#
# 0: 640x640 1 ball, 450.2ms
# Speed: 7.1ms preprocess, 450.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  228
# gt_y:  300
# pred_x:  228.50653076171875
# pred_y:  300.22735595703125
#
# 0: 640x640 (no detections), 266.8ms
# Speed: 7.0ms preprocess, 266.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 268.7ms
# Speed: 8.0ms preprocess, 268.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 371.8ms
# Speed: 8.0ms preprocess, 371.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  211
# gt_y:  301
# pred_x:  210.45956420898438
# pred_y:  301.2186279296875
#
# 0: 640x640 1 ball, 362.4ms
# Speed: 6.6ms preprocess, 362.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  209
# gt_y:  302
# pred_x:  208.40664672851562
# pred_y:  302.83245849609375
#
# 0: 640x640 (no detections), 360.0ms
# Speed: 8.0ms preprocess, 360.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 330.7ms
# Speed: 6.9ms preprocess, 330.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  210
# gt_y:  302
# pred_x:  209.21505737304688
# pred_y:  302.3743591308594
#
# 0: 640x640 2 balls, 371.5ms
# Speed: 9.0ms preprocess, 371.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  211
# gt_y:  303
# pred_x:  211.36392211914062
# pred_y:  303.5579833984375
# g_x:  211
# gt_y:  303
# pred_x:  211.08645629882812
# pred_y:  303.0002136230469
#
# 0: 640x640 2 balls, 386.2ms
# Speed: 8.0ms preprocess, 386.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  212
# gt_y:  305
# pred_x:  212.1295928955078
# pred_y:  306.18194580078125
# g_x:  212
# gt_y:  305
# pred_x:  212.2952880859375
# pred_y:  306.0041809082031
#
# 0: 640x640 2 balls, 402.1ms
# Speed: 8.0ms preprocess, 402.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  214
# gt_y:  308
# pred_x:  214.5374755859375
# pred_y:  307.94390869140625
# g_x:  214
# gt_y:  308
# pred_x:  214.96356201171875
# pred_y:  308.60540771484375
#
# 0: 640x640 2 balls, 382.3ms
# Speed: 9.0ms preprocess, 382.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  214
# gt_y:  309
# pred_x:  214.55438232421875
# pred_y:  307.9674377441406
# g_x:  214
# gt_y:  309
# pred_x:  214.96014404296875
# pred_y:  308.6175537109375
#
# 0: 640x640 1 ball, 464.3ms
# Speed: 8.0ms preprocess, 464.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  216
# gt_y:  312
# pred_x:  215.1025848388672
# pred_y:  312.144775390625
#
# 0: 640x640 (no detections), 519.9ms
# Speed: 9.9ms preprocess, 519.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 370.5ms
# Speed: 11.1ms preprocess, 370.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  219
# gt_y:  325
# pred_x:  219.6138916015625
# pred_y:  325.114013671875
#
# 0: 640x640 (no detections), 370.7ms
# Speed: 12.0ms preprocess, 370.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 373.2ms
# Speed: 9.0ms preprocess, 373.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 398.4ms
# Speed: 8.0ms preprocess, 398.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 3370.9ms
# Speed: 13.1ms preprocess, 3370.9ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  293
# gt_y:  234
# pred_x:  292.29107666015625
# pred_y:  235.3050994873047
#
# 0: 640x640 1 ball, 757.5ms
# Speed: 23.5ms preprocess, 757.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  297
# gt_y:  235
# pred_x:  296.90185546875
# pred_y:  235.39773559570312
#
# 0: 640x640 1 ball, 566.9ms
# Speed: 9.2ms preprocess, 566.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  303
# gt_y:  236
# pred_x:  304.57257080078125
# pred_y:  237.10107421875
#
# 0: 640x640 1 ball, 481.5ms
# Speed: 17.2ms preprocess, 481.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  304
# gt_y:  237
# pred_x:  304.57257080078125
# pred_y:  237.10162353515625
#
# 0: 640x640 1 ball, 1845.7ms
# Speed: 10.0ms preprocess, 1845.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  311
# gt_y:  240
# pred_x:  310.8804931640625
# pred_y:  239.6319580078125
#
# 0: 640x640 1 ball, 437.7ms
# Speed: 7.0ms preprocess, 437.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  318
# gt_y:  245
# pred_x:  318.496826171875
# pred_y:  244.11825561523438
#
# 0: 640x640 1 ball, 355.7ms
# Speed: 10.2ms preprocess, 355.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  327
# gt_y:  249
# pred_x:  327.0020751953125
# pred_y:  250.7194061279297
#
# 0: 640x640 (no detections), 325.4ms
# Speed: 8.0ms preprocess, 325.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 326.9ms
# Speed: 8.1ms preprocess, 326.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 ball, 416.9ms
# Speed: 7.9ms preprocess, 416.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# g_x:  346
# gt_y:  265
# pred_x:  345.92401123046875
# pred_y:  266.37823486328125
#
# 0: 640x640 (no detections), 354.0ms
# Speed: 8.0ms preprocess, 354.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 370.3ms
# Speed: 8.0ms preprocess, 370.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 399.3ms
# Speed: 7.9ms preprocess, 399.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 533.6ms
# Speed: 9.0ms preprocess, 533.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 360.7ms
# Speed: 9.0ms preprocess, 360.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
F1 = (2 * TP)/(2 * TP + FP + FN)
print(f'True Positive: {TP}')
print(f'False Positive: {FP}')
print(f'False Negative: {FN}')
print(f'F1 Score: {F1}')
# Out:
# True Positive: tensor([176.4134])
# False Positive: tensor([1.5118])
# False Negative: 309
# F1 Score: tensor([0.5319])
